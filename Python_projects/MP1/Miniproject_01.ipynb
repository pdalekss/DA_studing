# %%
import pandas as pd

# %% [markdown]
# Загрузите датасет bookings.csv.

# %%
df = pd.read_csv('bookings.csv', encoding = 'windows-1251', sep=';')

# %% [markdown]
# Приведите названия колонок к нижнему регистру и замените пробелы на знак нижнего подчеркивания.

# %%
df = df.rename(str.lower, axis = 'columns')
df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#           hotel  is_canceled  lead_time arrival_full_date  arrival_date_year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
# ...

# %% [markdown]
# Пользователи из каких стран совершили наибольшее число успешных бронирований? Укажите топ-5

# %%
df.groupby('country', as_index=False).agg({'is_canceled' : 'sum'}).sort_values('is_canceled').tail(6)
# Out:
#     country  is_canceled
# 43      DEU         1218
# 81      ITA         1333
# 56      FRA         1934
# 51      ESP         2177
# 59      GBR         2453
# 135     PRT        27519

# %% [markdown]
# На сколько ночей в среднем бронируют отели разных типов?

# %%
df['stays_total_nights'] = df.stays_in_weekend_nights + df.stays_in_week_nights

df.query("hotel == 'Resort Hotel'").agg({'stays_total_nights': 'mean'})
# Out:
# stays_total_nights    4.318547
# dtype: float64

# %%
df.query("hotel == 'City Hotel'").agg({'stays_total_nights': 'mean'})
# Out:
# stays_total_nights    2.978142
# dtype: float64

# %% [markdown]
# Иногда тип номера, полученного клиентом (assigned_room_type), отличается от изначально забронированного (reserved_room_type). Такое может произойти, например, по причине овербукинга. Сколько подобных наблюдений встретилось в датасете?

# %%
df.query("assigned_room_type != reserved_room_type").shape
# Out:
# (14917, 21)

# %% [markdown]
# Проанализируйте даты запланированного прибытия. – На какой месяц чаще всего успешно оформляли бронь в 2016? Изменился ли самый популярный месяц в 2017?– Сгруппируйте данные по годам и проверьте, на какой месяц бронирования отеля типа City Hotel отменялись чаще всего в каждый из периодов

# %%
df.query("arrival_date_year == 2017").groupby('arrival_date_month', as_index=False).count().sort_values('hotel')
# Out:
#   arrival_date_month  hotel  is_canceled  lead_time  arrival_full_date  \
# 3            January   3681         3681       3681               3681
# 2           February   4177         4177       4177               4177
# 1             August   4925         4925       4925               4925
# 6              March   4970         4970       4970               4970
# 4               July   5313         5313       5313               5313
# 5               June   5647         5647       5647               5647
# 0              April   5661         5661       5661               5661
# 7                May   6313         6313       6313               6313
#
#    arrival_date_year  arrival_date_week_number  arrival_date_day_of_month  \
# 3               3681                      3681                       3681
# 2               4177                      4177                       4177
# 1               4925                      4925                       4925
# ...

# %%
df.query("hotel == 'City Hotel' and is_canceled == 1").groupby('arrival_date_year', as_index=False).arrival_date_month.value_counts()
# Out:
#     arrival_date_year arrival_date_month  count
# 0                2015          September   1543
# 1                2015            October   1321
# 2                2015             August   1232
# 3                2015               July    939
# 4                2015           December    668
# 5                2015           November    301
# 6                2016            October   1947
# 7                2016               June   1720
# 8                2016          September   1567
# 9                2016              April   1539
# 10               2016                May   1436
# 11               2016           November   1360
# 12               2016             August   1247
# 13               2016              March   1108
# 14               2016           December   1072
# 15               2016               July   1043
# 16               2016           February    930
# 17               2016            January    438
# 18               2017                May   2217
# ...

# %% [markdown]
# Посмотрите на числовые характеристики трёх переменных: adults, children и babies. Какая из них имеет наибольшее среднее значение?

# %%
df.adults.mean()
# Out:
# 1.8564033838679956

# %%
df.children.mean()
# Out:
# 0.10388990333874994

# %%
df.babies.mean()
# Out:
# 0.007948739425412514

# %% [markdown]
# Создайте колонку total_kids, объединив children и babies. Для отелей какого типа среднее значение переменной оказалось наибольшим?

# %%
df['total_kids'] = df.children + df.babies

# %%
df.groupby('hotel', as_index=False).agg({'total_kids':'mean'})
# Out:
#           hotel  total_kids
# 0    City Hotel    0.096311
# 1  Resort Hotel    0.142586

# %% [markdown]
# Создайте переменную has_kids, которая принимает значение True, если клиент при бронировании указал хотя бы одного ребенка (total_kids), в противном случае – False. Посчитайте отношение количества ушедших пользователей к общему количеству клиентов, выраженное в процентах (churn rate). Укажите, среди какой группы показатель выше.

# %%
df['has_kids'] = df['total_kids'] != 0

# %%
chr_with_kids = df.query('has_kids == True and is_canceled == 1').shape[0] / df.query('has_kids == True').shape[0] * 100
chr_without_kids = df.query('has_kids == False and is_canceled == 1').shape[0] / df.query('has_kids == False').shape[0] * 100
print(chr_with_kids, chr_without_kids)
# Out:
# 34.950728363324764 37.219001581042036
